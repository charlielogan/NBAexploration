# %%
import pandas as pd
import sqlite3
import os

import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.stats import diagnostic as diag
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %matplotlib inline

# %%
# Open SQL Database and initialize dataframe
path = "../Algorithm"
conn = sqlite3.connect(path + "/Prediction.db")
df = pd.read_sql_query("SELECT * FROM BLAZERS", conn)

# %%
# Add remaining teams to the end of the dataframe
teams = ["BLAZERS", "BUCKS", "BULLS", "CAVALIERS", "CELTICS", "CLIPPERS", "GRIZZLIES", "HAWKS", "HEAT", "HORNETS", "JAZZ", "KINGS", "KNICKS", "LAKERS", "MAGIC", "MAVERICKS", "NETS", "NUGGETS", "PACERS", "PELICANS", "PISTONS", "RAPTORS", "ROCKETS", "SIXERS", "SPURS", "SUNS", "THUNDER", "TIMBERWOLVES", "WARRIORS", "WIZARDS"]

for team in teams[1:]:
    temp_df = pd.read_sql_query("SELECT * FROM " + team, conn)
    df = pd.concat([df, temp_df], axis=0)

# %%
df
# Out:
#        game_ID  time_remaining  end_minutes_played  turnovers  attempt_3pt  \
# 0           12            2741                 240       39.0         60.0
# 1           12            2715                 240       39.0         60.0
# 2           12            2682                 240       39.0         60.0
# 3           12            2655                 240       39.0         60.0
# 4           12            2626                 240       39.0         60.0
# 5           12            2600                 240       39.0         60.0
# 6           12            2555                 240       39.0         60.0
# 7           12            2526                 240       39.0         60.0
# 8           12            2506                 240       39.0         60.0
# 9           12            2478                 240       39.0         60.0
# 10          12            2459                 240       39.0         60.0
# 11          12            2443                 240       39.0         60.0
# 12          12            2403                 240       39.0         60.0
# 13          12            2385                 240       39.0         60.0
# 14          12            2361                 240       39.0         60.0
# 15          12            2337                 240       39.0         60.0
# 16          12            2284                 240       39.0         60.0
# 17          12            2236                 240       39.0         60.0
# 18          12            2206                 240       39.0         60.0
# 19          12            2198                 240       39.0         60.0
# 20          12            2160                 240       39.0         60.0
# 21          12            2103                 240       39.0         60.0
# 22          12            2061                 240       39.0         60.0
# 23          12            2029                 240       39.0         60.0
# 24          12            1996                 240       39.0         60.0
# 25          12            1987                 240       39.0         60.0
# 26          12            1958                 240       39.0         60.0
# 27          12            1919                 240       39.0         60.0
# 28          12            1878                 240       39.0         60.0
# 29          12            1833                 240       39.0         60.0
# ...        ...             ...                 ...        ...          ...
# 13268     1259            1191                 240       22.0         59.0
# 13269     1259            1147                 240       22.0         59.0
# 13270     1259            1073                 240       22.0         59.0
# 13271     1259            1046                 240       22.0         59.0
# 13272     1259            1003                 240       22.0         59.0
# 13273     1259             977                 240       22.0         59.0
# 13274     1259             919                 240       22.0         59.0
# 13275     1259             903                 240       22.0         59.0
# 13276     1259             852                 240       22.0         59.0
# 13277     1259             830                 240       22.0         59.0
# 13278     1259             777                 240       22.0         59.0
# 13279     1259             751                 240       22.0         59.0
# 13280     1259             720                 240       22.0         59.0
# 13281     1259             658                 240       22.0         59.0
# 13282     1259             643                 240       22.0         59.0
# 13283     1259             613                 240       22.0         59.0
# 13284     1259             585                 240       22.0         59.0
# 13285     1259             525                 240       22.0         59.0
# 13286     1259             502                 240       22.0         59.0
# 13287     1259             450                 240       22.0         59.0
# 13288     1259             426                 240       22.0         59.0
# 13294          183     109.2      107.4     108.0      105.4
# 13295          183     109.2      107.4     108.0      105.4
# 13296          183     109.2      107.4     108.0      105.4
# 13297          183     109.2      107.4     108.0      105.4
#
# [392819 rows x 21 columns]

# %%
# Filter out First 10 minutes of game
df = df[df["time_remaining"] < 2280]

# Filter out last 5 minutes of game
df = df[df["time_remaining"] > 300]

# Filter out overtime games
df = df[df['end_minutes_played'] == 240]

# %%
# delete unusable variables
del df["game_ID"]
del df["time_remaining"]
del df['end_minutes_played']
del df['made_3pt']
del df['attempt_3pt']
del df["fg_made"]
del df["fg_attempt"]
del df['fg_percent']
del df['ft_percent']
del df['ft_attempt']
del df['ft_made']

# %%
df['home_points_avg'] = df['home_ppg'] + df['home_oppg']
df['away_points_avg'] = df['away_ppg'] + df['away_oppg']
del df['total_score']
del df['turnovers']
del df['home_ppg']
del df['home_oppg']
del df['away_ppg']
del df['away_oppg']
#del df['score_diff']

# %%
df.sample(10)
# Out:
#       percent_3pt  score_diff  score_rate  final_score  home_points_avg  \
# 7840     0.417910           6    0.069384          206            211.6
# 8435     0.325581           3    0.070938          214            213.3
# 1271     0.254902          29    0.078452          224            221.2
# 3806     0.425532          10    0.086301          258            229.4
# 6228     0.540984           5    0.081274          247            216.2
# 2431     0.337500           7    0.077023          219            226.0
# 700      0.276923          12    0.073230          203            219.8
# 3645     0.357143           7    0.104396          255            229.5
# 3679     0.388889          13    0.079622          222            229.4
# 9253     0.363636           5    0.068534          200            207.7
#
#       away_points_avg
# 7840            216.2
# 8435            217.2
# 1271            226.5
# 3806            225.2
# 6228            213.3
# 2431            219.1
# 700             217.8
# 3645            228.9
# 3679            222.8
# 9253            216.2

# %%
sns.pairplot(df)

# %%
# check for multicolinearity
corr = df.corr()
display(corr)

sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')
# Out:
#                  percent_3pt  score_rate  final_score  home_points_avg  \
# percent_3pt         1.000000    0.340042     0.445504        -0.000857
# score_rate          0.340042    1.000000     0.700473         0.301038
# final_score         0.445504    0.700473     1.000000         0.396157
# home_points_avg    -0.000857    0.301038     0.396157         1.000000
# away_points_avg    -0.004241    0.316214     0.398405         0.411695
#
#                  away_points_avg
# percent_3pt            -0.004241
# score_rate              0.316214
# final_score             0.398405
# home_points_avg         0.411695
# away_points_avg         1.000000

# %%
# Heatmap tells us that score_rate, time_remaining, and score_diff are uncorrelated enough to include. 

# the VFI does expect a constant term in the data, so we need to add one using the add_constant method
X1 = sm.tools.add_constant(df)


# create the series for both
series_before = pd.Series([variance_inflation_factor(X1.values, i) for i in range(X1.shape[1])], index=X1.columns)


# display the series
print('DATA BEFORE')
print('-'*100)
display(series_before)
# Out:
# DATA BEFORE
# ----------------------------------------------------------------------------------------------------
# const              1123.480653
# percent_3pt           1.351687
# score_diff            1.005594
# score_rate            1.979297
# final_score           2.568702
# home_points_avg       1.340290
# away_points_avg       1.350134
# dtype: float64

# %%
# Given all of our variables have low correlation values (well under 5), we can confirm they are okay to be included
desc = df.describe()
desc
# Out:
#          percent_3pt     score_diff     score_rate    final_score  \
# count  280047.000000  280047.000000  280047.000000  280047.000000
# mean        0.356220       9.253932       0.074937     215.816970
# std         0.062480       7.305137       0.009475      19.951563
# min         0.133333       0.000000       0.024828     144.000000
# 25%         0.312500       4.000000       0.068864     202.000000
# 50%         0.356164       8.000000       0.074717     216.000000
# 75%         0.396552      13.000000       0.080738     229.000000
# max         0.611111      63.000000       0.282862     317.000000
#
#        home_points_avg  away_points_avg
# count    280047.000000    280047.000000
# mean        217.100683       217.107728
# std           8.118844         8.177520
# min         197.500000       197.500000
# 25%         212.200000       212.200000
# 50%         217.400000       217.400000
# 75%         222.500000       222.800000
# max         235.300000       235.300000

# %%
#build the model

X = df.drop('final_score', axis = 1)
Y = df["final_score"]

#Split data into test and train
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=1)

# Fit the model
regression_model = LinearRegression()
regression_model.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Print out results of the model
intercept = regression_model.intercept_
coefficent = regression_model.coef_[0]

print("The intercept for our model is {:.4}".format(intercept))
print('-'*100)

for coef in zip(X.columns, regression_model.coef_):
    print("The Coefficient for {} is {:.2}".format(coef[0],coef[1]))
# Out:
# The intercept for our model is -78.18
# ----------------------------------------------------------------------------------------------------
# The Coefficient for percent_3pt is 8.8e+01
# The Coefficient for score_diff is 0.039
# The Coefficient for score_rate is 1e+03
# The Coefficient for home_points_avg is 0.43
# The Coefficient for away_points_avg is 0.41

# %%
Y_predict = regression_model.predict(X_test)

# %%
Y_predict
# Out:
# array([246.42967393, 236.78014726, 227.61098657, ..., 208.25884128,
#        235.45603608, 210.20552433])

# %%
print('Train Score :', regression_model.score(X_train,Y_train))
print('Test Score:', regression_model.score(X_test,Y_test))
# Out:
# Train Score : 0.6100693347046582
# Test Score: 0.6132168580398526

# %%
# Applying model to be used with the statsmodel package (needs a constant) 
X2 = sm.add_constant(X)

# create a OLS model
model = sm.OLS(Y, X2)

# fit the data
est = model.fit()

# %%
#White's test for heteroscedasticity
_, pval, __, f_pval = diag.het_white(est.resid, est.model.exog, retres = False)
print(pval, f_pval)
print('-'*100)

_, pval, __, f_pval = diag.het_breuschpagan(est.resid, est.model.exog)
print(pval, f_pval)
print('-'*100)
# Out:
# 0.0 0.0
# ----------------------------------------------------------------------------------------------------
# 0.0 0.0
# ----------------------------------------------------------------------------------------------------

# %%
# test for autocorrelation

from statsmodels.stats.stattools import durbin_watson

test_results = diag.acorr_ljungbox(est.resid)
ibvalue, p_val = test_results

if min(p_val) > 0.05:
    print("The lowest p-value found was {:.4}".format(min(p_val)))
    print("We fail to reject the null hypthoesis, so there is no autocorrelation.")
    print('-'*100)
else:
    print("The lowest p-value found was {:.4}".format(min(p_val)))
    print("We reject the null hypthoesis, so there is autocorrelation.")
    print('-'*100)
    
sm.graphics.tsa.plot_acf(est.resid)
plt.show()
# Out:
# The lowest p-value found was 0.0
# We reject the null hypthoesis, so there is autocorrelation.
# ----------------------------------------------------------------------------------------------------

# %%
import pylab

# check for the normality of the residuals
sm.qqplot(est.resid, line='s')
pylab.show()

mean_residuals = sum(est.resid)/ len(est.resid)
print("The mean of the residuals is {:.4}".format(mean_residuals))
# Out:
# The mean of the residuals is 1.144e-11

# %%
import math
# calculate the mean squared error
model_mse = mean_squared_error(Y_test, Y_predict)

# calculate the mean absolute error
model_mae = mean_absolute_error(Y_test, Y_predict)

# calulcate the root mean squared error
model_rmse =  math.sqrt(model_mse)

# display the output
print("MSE {:.3}".format(model_mse))
print("MAE {:.3}".format(model_mae))
print("RMSE {:.3}".format(model_rmse))
# Out:
# MSE 1.54e+02
# MAE 9.53
# RMSE 12.4

# %%
model_r2 = r2_score(Y_test, Y_predict)
print("R2: {:.2}".format(model_r2))
# Out:
# R2: 0.61

# %%
est.conf_int()
# Out:
#                            0            1
# const             -79.606987   -76.570794
# percent_3pt        87.373363    88.960100
# score_diff          0.032204     0.044859
# score_rate       1045.706350  1056.968413
# home_points_avg     0.426908     0.439659
# away_points_avg     0.404909     0.417652

# %%
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            final_score   R-squared:                       0.611
# Model:                            OLS   Adj. R-squared:                  0.611
# Method:                 Least Squares   F-statistic:                 8.786e+04
# Date:                Mon, 18 May 2020   Prob (F-statistic):               0.00
# Time:                        17:03:10   Log-Likelihood:            -1.1035e+06
# No. Observations:              280047   AIC:                         2.207e+06
# Df Residuals:                  280041   BIC:                         2.207e+06
# Df Model:                           5
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             -78.0889      0.775   -100.818      0.000     -79.607     -76.571
# percent_3pt        88.1667      0.405    217.811      0.000      87.373      88.960
# score_diff          0.0385      0.003     11.935      0.000       0.032       0.045
# score_rate       1051.3374      2.873    365.935      0.000    1045.706    1056.968
# home_points_avg     0.4333      0.003    133.198      0.000       0.427       0.440
# away_points_avg     0.4113      0.003    126.512      0.000       0.405       0.418
# ==============================================================================
# Omnibus:                    42759.616   Durbin-Watson:                   0.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           546596.180
# Skew:                          -0.315   Prob(JB):                         0.00
# Kurtosis:                       9.815   Cond. No.                     3.76e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.76e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import pickle

# pickle the model
with open('my_mulitlinear_regression.sav','wb') as f:
     pickle.dump(regression_model, f)

# load it back in
with open('my_mulitlinear_regression.sav', 'rb') as pickle_file:
     regression_model_2 = pickle.load(pickle_file)

# make a new prediction
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-ec5c11601d74> in <module>
#      10
#      11 # make a new prediction
# ---> 12 regression_model_2.predict([[0, 0.030303]])
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     197         return safe_sparse_dot(X, self.coef_.T,
# --> 198                                dense_output=True) + self.intercept_
#     199
#     200     def predict(self, X):
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     171         return ret
#     172     else:
# --> 173         return np.dot(a, b)
#     174
#     175
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (1,2) and (5,) not aligned: 2 (dim 1) != 5 (dim 0)

# %%
home_score = int(input("Enter home team score "))
away_score = int(input("Enter away team score "))
q = int(input("What quarter is it? "))
m = int(input("How many minutes are left? "))
s = int(input("How many seconds are left? "))
three = int(input("What is the three point percentage? "))
home = float(input("Season average points total for home team: "))
away = float(input("Season average points total for away team: "))

remaining = m*60 + s + (720*(4-q))
score_rate = float(home_score + away_score)/float(remaining)
tpp = float(three)/100

ans = regression_model_2.predict([[tpp, abs(home_score-away_score), score_rate, home, away]])
print("Your estimated total final: " + str(ans[0]))
# Out:
# Enter home team score 62
# Enter away team score 64
# What quarter is it? 3
# How many minutes are left? 6
# How many seconds are left? 21
# What is the three point percentage? 36
# Season average points total for home team: 119.8
