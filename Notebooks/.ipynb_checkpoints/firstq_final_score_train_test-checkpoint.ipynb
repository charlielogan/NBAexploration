# %%
import pandas as pd
import sqlite3
import os

import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.stats import diagnostic as diag
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %matplotlib inline

# %%
# Open SQL Database and initialize dataframe
path = "../Algorithm/data"
conn = sqlite3.connect("C:\\Users\\charl\\Desktop\\Algorithm\\data\\Prediction.db")
df = pd.read_sql_query("SELECT * FROM BLAZERS", conn)

# %%
# Add remaining teams to the end of the dataframe
teams = ["BLAZERS", "BUCKS", "BULLS", "CAVALIERS", "CELTICS", "CLIPPERS", "GRIZZLIES", "HAWKS", "HEAT", "HORNETS", "JAZZ", "KINGS", "KNICKS", "LAKERS", "MAGIC", "MAVERICKS", "NETS", "NUGGETS", "PACERS", "PELICANS", "PISTONS", "RAPTORS", "ROCKETS", "SIXERS", "SPURS", "SUNS", "THUNDER", "TIMBERWOLVES", "WARRIORS", "WIZARDS"]

for team in teams[1:]:
    temp_df = pd.read_sql_query("SELECT * FROM " + team, conn)
    df = pd.concat([df, temp_df], axis=0)

# %%
df
# Out:
#       game_ID   game_date home_team     away_team  TO_1  three_m1  three_a1  \
# 0    21901289  2020-08-09   BLAZERS        SIXERS     7         4        12
# 1    21901280  2020-08-08   BLAZERS      CLIPPERS     8         8        15
# 2    21901261  2020-08-04   BLAZERS       ROCKETS     6         8        21
# 3    21901234  2020-07-31   BLAZERS     GRIZZLIES     6         6        14
# 4    21900966  2020-03-10   BLAZERS          SUNS     6         7        15
# ..        ...         ...       ...           ...   ...       ...       ...
# 283  21300189  2013-11-23   WIZARDS        KNICKS     9         5        11
# 284  21300156  2013-11-19   WIZARDS  TIMBERWOLVES     5         5        11
# 285  21300138  2013-11-16   WIZARDS     CAVALIERS    16         2        10
# 286  21300077  2013-11-08   WIZARDS          NETS     4         6        13
# 287  21300022  2013-11-01   WIZARDS        SIXERS     8         4        15
#
#      ts_1  diff_1  TO_2  ...  TO_3  three_m3  three_a3  ts_3  diff_3  \
# 0      52      14     6  ...    10         5        16   183       1
# 1      71       3     7  ...     7         7        22   191       1
# 2      53       5     4  ...     7         7        18   166       6
# 3      65       5     9  ...     7         7        14   189       3
# 4      64       8     8  ...     7         6        17   160       4
# ..    ...     ...   ...  ...   ...       ...       ...   ...     ...
# 283    53       1     4  ...     5         4        18   145       7
# 284    61       7     2  ...     9         4        12   162       0
# 285    43       7     8  ...     5         1         6   133       5
# 286    60       6     9  ...    12         1        13   146       0
# 287    54      12    14  ...     5         2        10   148       0
#
#      ts_final  home_ppg  home_oppg  away_ppg  away_oppg
# 0       245.0     115.0      116.1     110.7      108.4
# 1       239.0     115.0      116.1     116.3      109.9
# 2       212.0     115.0      116.1     117.8      114.8
# 3       275.0     115.0      116.1     112.6      113.7
# 4       236.4     115.0      116.1     113.6      113.4
# ..        ...       ...        ...       ...        ...
# 283     187.0     100.7       99.4      98.6       99.4
# 284     204.0     100.7       99.4     106.9      104.3
# 285     199.0     100.7       99.4      98.2      101.5
# 286     220.0     100.7       99.4      98.5       99.5
# 287     211.0     100.7       99.4      99.5      109.9
#
# [8527 rows x 24 columns]

# %%
#df.to_csv("../data/2016-2018_save.csv")

# %%
df.head()
# Out:
#     game_ID   game_date home_team  away_team  TO_1  three_m1  three_a1  ts_1  \
# 0  21901289  2020-08-09   BLAZERS     SIXERS     7         4        12    52
# 1  21901280  2020-08-08   BLAZERS   CLIPPERS     8         8        15    71
# 2  21901261  2020-08-04   BLAZERS    ROCKETS     6         8        21    53
# 3  21901234  2020-07-31   BLAZERS  GRIZZLIES     6         6        14    65
# 4  21900966  2020-03-10   BLAZERS       SUNS     6         7        15    64
#
#    diff_1  TO_2  ...  TO_3  three_m3  three_a3  ts_3  diff_3  ts_final  \
# 0      14     6  ...    10         5        16   183       1     245.0
# 1       3     7  ...     7         7        22   191       1     239.0
# 2       5     4  ...     7         7        18   166       6     212.0
# 3       5     9  ...     7         7        14   189       3     275.0
# 4       8     8  ...     7         6        17   160       4     236.4
#
#    home_ppg  home_oppg  away_ppg  away_oppg
# 0     115.0      116.1     110.7      108.4
# 1     115.0      116.1     116.3      109.9
# 2     115.0      116.1     117.8      114.8
# 3     115.0      116.1     112.6      113.7
# 4     115.0      116.1     113.6      113.4
#
# [5 rows x 24 columns]

# %%
df['avg_points_scored'] = (df['home_ppg'] + df['away_ppg'])/2
df['avg_points_allowed'] = (df['home_oppg'] + df['away_oppg'])/2
df["TO_2"] = df["TO_2"] + df["TO_1"]
df['TO_3'] = df["TO_3"] + df["TO_2"]
df["three_a2"] = df["three_a2"] + df["three_a1"]
df['three_a3'] = df["three_a3"] + df["three_a2"]
df["three_m2"] = df["three_m2"] + df["three_m1"]
df['three_m3'] = df["three_m3"] + df["three_m2"]

# %%
df.head()
# Out:
#     game_ID   game_date home_team  away_team  TO_1  three_m1  three_a1  ts_1  \
# 0  21901289  2020-08-09   BLAZERS     SIXERS     7         4        12    52
# 1  21901280  2020-08-08   BLAZERS   CLIPPERS     8         8        15    71
# 2  21901261  2020-08-04   BLAZERS    ROCKETS     6         8        21    53
# 3  21901234  2020-07-31   BLAZERS  GRIZZLIES     6         6        14    65
# 4  21900966  2020-03-10   BLAZERS       SUNS     6         7        15    64
#
#    diff_1  TO_2  ...  three_a3  ts_3  diff_3  ts_final  home_ppg  home_oppg  \
# 0      14    13  ...        44   183       1     245.0     115.0      116.1
# 1       3    15  ...        57   191       1     239.0     115.0      116.1
# 2       5    10  ...        62   166       6     212.0     115.0      116.1
# 3       5    15  ...        46   189       3     275.0     115.0      116.1
# 4       8    14  ...        49   160       4     236.4     115.0      116.1
#
#    away_ppg  away_oppg  avg_points_scored  avg_points_allowed
# 0     110.7      108.4             112.85              112.25
# 1     116.3      109.9             115.65              113.00
# 2     117.8      114.8             116.40              115.45
# 3     112.6      113.7             113.80              114.90
# 4     113.6      113.4             114.30              114.75
#
# [5 rows x 26 columns]

# %%
# delete unusable variables
# Score diff helpful for 3q, not for 1st
#df = df[['ts_1','ts_final', 'home_ppg', 'home_oppg', 'away_ppg', 'away_oppg']]
df = df[['ts_1','ts_final', 'avg_points_scored', 'avg_points_allowed']]

# %%
#df['percent_3pt'] = df['three_m1']/df['three_a1']

# %%
df.sample(20)
# Out:
#      ts_1  ts_final  home_ppg  home_oppg  away_ppg  away_oppg
# 187    43     235.0     102.0      101.4     105.7      102.5
# 15     53     224.0     112.6      113.7     106.3      115.0
# 12     64     210.0     112.0      109.1     113.7      107.3
# 197    48     193.0      97.3      106.9     102.7       98.2
# 180    56     237.0     106.5      106.4     102.0      101.4
# 9      50     217.0     113.3      117.5     110.4      108.4
# 113    55     211.0     103.4      108.2     104.5      108.0
# 29     50     195.0     105.8      112.3     106.9      114.8
# 145    47     204.0     104.3      108.0     102.8      106.7
# 264    28     163.0     101.0      101.5     107.7      103.1
# 53     39     239.0     112.2      112.3     104.9      113.4
# 192    52     209.0     100.9      107.5     102.4      106.0
# 259    66     221.0     100.7       99.4      96.5      102.0
# 12     50     221.0     106.8      109.9     114.4      119.1
# 53     57     226.0     107.3      106.6     118.1      109.3
# 5      50     250.0     111.8      119.7     107.3      108.3
# 230    46     192.0     105.2      102.3     103.2       97.0
# 229    55     178.0     100.8       97.8      98.0      100.9
# 79     51     170.0     110.0      108.5     105.6      103.0
# 66     68     253.0     111.7      110.0     111.8      113.5

# %%
# check for multicolinearity
corr = df.corr()
display(corr)

sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')
# Out:
#                ts_1  ts_final  home_ppg  home_oppg  away_ppg  away_oppg
# ts_1       1.000000  0.571701  0.281835   0.264051  0.286587   0.298469
# ts_final   0.571701  1.000000  0.401650   0.381823  0.398111   0.395710
# home_ppg   0.281835  0.401650  1.000000   0.670625  0.541940   0.567761
# home_oppg  0.264051  0.381823  0.670625   1.000000  0.567813   0.571962
# away_ppg   0.286587  0.398111  0.541940   0.567813  1.000000   0.670411
# away_oppg  0.298469  0.395710  0.567761   0.571962  0.670411   1.000000
# <AxesSubplot:>

# %%
# Given all of our variables have low correlation values (well under 5), we can confirm they are okay to be included
desc = df.describe()
desc
# Out:
#               ts_1     ts_final     home_ppg    home_oppg     away_ppg  \
# count  8527.000000  8527.000000  8527.000000  8527.000000  8527.000000
# mean     52.689340   210.297432   105.442547   105.467714   105.440624
# std       8.675802    22.361762     5.865123     5.646631     5.864585
# min      20.000000     0.800000    91.900000    91.800000    91.900000
# 25%      47.000000   195.000000   101.450000   101.200000   101.450000
# 50%      52.000000   209.000000   104.800000   105.400000   104.800000
# 75%      58.000000   225.000000   110.000000   109.100000   110.000000
# max      89.000000   329.000000   118.700000   119.700000   118.700000
#
#          away_oppg
# count  8527.000000
# mean    105.456280
# std       5.633126
# min      91.800000
# 25%     101.200000
# 50%     105.300000
# 75%     109.100000
# max     119.700000

# %%
#df = df[df['diff_1'] < 29]
df = df[df['ts_final'] > 100]
df = df[df['ts_final'] < 310]

# %%
#build the model
X = df.drop('ts_final', axis = 1)
Y = df["ts_final"]

#Split data into test and train
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# Fit the model
regression_model = LinearRegression()
regression_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Print out results of the model
intercept = regression_model.intercept_
coefficent = regression_model.coef_[0]

print("The intercept for our model is {:.4}".format(intercept))
print('-'*100)

for coef in zip(X.columns, regression_model.coef_):
    print("The Coefficient for {} is {:.2}".format(coef[0],coef[1]))
# Out:
# The intercept for our model is -12.78
# ----------------------------------------------------------------------------------------------------
# The Coefficient for ts_1 is 1.2
# The Coefficient for home_ppg is 0.46
# The Coefficient for home_oppg is 0.34
# The Coefficient for away_ppg is 0.4
# The Coefficient for away_oppg is 0.31

# %%
Y_predict = regression_model.predict(X_test)

# %%
Y_predict
# Out:
# array([215.4927381 , 219.99638259, 221.13093848, ..., 221.65643949,
#        223.81415222, 199.17481396])

# %%
print('Train Score :', regression_model.score(X_train,Y_train))
print('Test Score:', regression_model.score(X_test,Y_test))
# Out:
# Train Score : 0.44552129186646594
# Test Score: 0.39997392653305286

# %%
# Applying model to be used with the statsmodel package (needs a constant) 
X2 = sm.add_constant(X)

# create a OLS model
model = sm.OLS(Y, X2)


# fit the data
est = model.fit()
est.pvalues
# TO, ts, all pgg
# Out:
# const        6.124291e-03
# ts_1         0.000000e+00
# home_ppg     9.531475e-27
# home_oppg    1.089119e-12
# away_ppg     4.043624e-20
# away_oppg    2.665692e-12
# dtype: float64

# %%
#White's test for heteroscedasticity
_, pval, __, f_pval = diag.het_white(est.resid, est.model.exog)
print(pval, f_pval)
print('-'*100)

if pval > 0.05:
    print("For the White's Test")
    print("The p-value was {:.4}".format(pval))
    print("We fail to reject the null hypthoesis, so there is no heterosecdasticity. \n")
    
else:
    print("For the White's Test")
    print("The p-value was {:.4}".format(pval))
    
_, pval, __, f_pval = diag.het_breuschpagan(est.resid, est.model.exog)
print(pval, f_pval)
print('-'*100)
# Out:
# 1.1855824134262218e-25 6.156703289772872e-26
# ----------------------------------------------------------------------------------------------------
# For the White's Test
# The p-value was 1.186e-25
# 8.196165752292955e-14 7.250922394289883e-14
# ----------------------------------------------------------------------------------------------------

# %%
model = sm.OLS(Y, X2)
est = model.fit()

_, pval, __, f_pval = diag.het_white(est.resid, est.model.exog)
print(pval, f_pval)
# Out:
# 1.1855824134262218e-25 6.156703289772872e-26

# %%
import pylab

# check for the normality of the residuals
sm.qqplot(est.resid, line='s')
pylab.show()

mean_residuals = sum(est.resid)/ len(est.resid)
print("The mean of the residuals is {:.4}".format(mean_residuals))
# Out:
# The mean of the residuals is 7.821e-14

# %%
import math
# calculate the mean squared error
model_mse = mean_squared_error(Y_test, Y_predict)

# calculate the mean absolute error
model_mae = mean_absolute_error(Y_test, Y_predict)

# calulcate the root mean squared error
model_rmse =  math.sqrt(model_mse)

# display the output
print("MSE {:.3}".format(model_mse))
print("MAE {:.3}".format(model_mae))
print("RMSE {:.3}".format(model_rmse))
# Out:
# MSE 2.66e+02
# MAE 12.8
# RMSE 16.3

# %%
model_r2 = r2_score(Y_test, Y_predict)
print("R2: {:.2}".format(model_r2))
# Out:
# R2: 0.4

# %%
est.conf_int()
# Out:
#                    0         1
# const     -18.366322 -3.052581
# ts_1        1.134996  1.220169
# home_ppg    0.379842  0.549407
# home_oppg   0.235400  0.413930
# away_ppg    0.313515  0.483056
# away_oppg   0.231027  0.410582

# %%
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ts_final   R-squared:                       0.437
# Model:                            OLS   Adj. R-squared:                  0.437
# Method:                 Least Squares   F-statistic:                     1323.
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):               0.00
# Time:                        14:11:33   Log-Likelihood:                -35893.
# No. Observations:                8520   AIC:                         7.180e+04
# Df Residuals:                    8514   BIC:                         7.184e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -10.7095      3.906     -2.742      0.006     -18.366      -3.053
# ts_1           1.1776      0.022     54.204      0.000       1.135       1.220
# home_ppg       0.4646      0.043     10.743      0.000       0.380       0.549
# home_oppg      0.3247      0.046      7.130      0.000       0.235       0.414
# away_ppg       0.3983      0.043      9.210      0.000       0.314       0.483
# away_oppg      0.3208      0.046      7.005      0.000       0.231       0.411
# ==============================================================================
# Omnibus:                      166.819   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              299.021
# Skew:                           0.147   Prob(JB):                     1.17e-65
# Kurtosis:                       3.869   Cond. No.                     4.80e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.8e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import pickle

# pickle the model
with open('../Models/predict_1.sav','wb') as f:
     pickle.dump(regression_model, f)
